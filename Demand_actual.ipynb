# %%
import requests
from bs4 import BeautifulSoup
import zipfile
import os
import time

# %%
# Fetch the webpage
url = "https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/"
response = requests.get(url)

# Parse the HTML
soup = BeautifulSoup(response.text, 'html.parser')

# Find all links to ZIP files
zip_links = [a['href'] for a in soup.find_all('a') if a['href'].endswith('.zip')]

for link in zip_links:
    # Correct the URL construction
    full_url = "https://nemweb.com.au" + link
    file_name = link.split('/')[-1]
    
    base = "./Acual_Demand"
    file_path = os.path.join(base, file_name)
    print(f"Attempting to download: {full_url}")
    
    r = requests.get(full_url, stream=True)

    with open(file_path, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
# Out:
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230723.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230730.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230806.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230813.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230820.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230827.zip
# Attempting to download: https://nemweb.com.au/Reports/Archive/Operational_Demand/Actual_HH/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230903.zip
# ...

# %%
from zipfile import ZipFile
files = os.listdir("./Actual_Demand")
zip_files = [f for f in files if f.endswith('.zip')]
zip_files.sort()
print(zip_files)


for file in zip_files:
    file = os.path.join("./Actual_Demand" , file)
    date_str = file.split('_')[-1].replace('.zip', '')

    new_dir = f"./Actual_Demand_sub/{date_str}"
    os.makedirs(new_dir,exist_ok=True)
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(new_dir)
# Out:
# ['PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230723.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230730.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230806.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230813.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230820.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230827.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230903.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230910.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230917.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20230924.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231001.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231008.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231015.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231022.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231029.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231105.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231112.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231119.zip', 'PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_20231126.zip', 'PUBLIC_A
# ...

# %%
subFolders = os.listdir("./Actual_Demand_sub")
subFolders.sort()

print(subFolders)
for folder in subFolders:
    if "DS_Store" in folder:
        continue
    
    base = os.path.join("./Actual_Demand_sub",folder)
    files = os.listdir(base)
    
    files.sort()
    new_dir = f"./Actual_Demand_sub/{folder}_csv"
    
    os.makedirs(new_dir,exist_ok=True)
    for file in files:
        
        file = os.path.join(base,file)
        print(file)
        with zipfile.ZipFile(file, 'r') as zip_ref:
            zip_ref.extractall(new_dir)
# Out:
# ['20230723', '20230730', '20230806', '20230813', '20230820', '20230827', '20230903', '20230910', '20230917', '20230924', '20231001', '20231008', '20231015', '20231022', '20231029', '20231105', '20231112', '20231119', '20231126', '20231203', '20231210', '20231217', '20231224', '20231231', '20240107', '20240114', '20240121', '20240128', '20240204', '20240211', '20240218', '20240225', '20240303', '20240310', '20240317', '20240324', '20240331', '20240407', '20240414', '20240421', '20240428', '20240505', '20240512', '20240519', '20240526', '20240602', '20240609', '20240616', '20240623', '20240630', '20240707', '20240714', '20240721', '20240728', '20240804', '20240811']
# ./Actual_Demand_sub/20230723/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_202307230000_20230723000003.zip
# ./Actual_Demand_sub/20230723/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_202307230030_20230723003002.zip
# ./Actual_Demand_sub/20230723/PUBLIC_ACTUAL_OPERATIONAL_DEMAND_HH_202307230100_20230723010002.zip
# ...

# %%
import pandas as pd
import numpy as np

base = "./Actual_Demand_sub"
csvfolders = os.listdir(base)
csvfolders = [f for f in csvfolders if "csv" in f]
csvfolders.sort()

for csvfolder in csvfolders:
    folderpath = os.path.join(base,csvfolder)
    csvfiles = os.listdir(folderpath)
    csvfiles.sort()
    for file in csvfiles:
        folder_path = os.path.join(base,csvfolder)
        file_path = os.path.join(folder_path,file)
        
        

        df = pd.read_csv(file_path,skiprows=1, header=0,index_col=False)

        
        new_df = df[['INTERVAL_DATETIME', 'REGIONID', 'OPERATIONAL_DEMAND.1']].copy()


        new_df.columns = ['Date', 'Region', 'OPERATIONAL_DEMAND']
        new_df = new_df.dropna()

        if os.path.isfile("Actual_Demand.csv"):

            new_df.to_csv("Actual_Demand.csv", mode='a', header=False, index=False)
        else:
            new_df.to_csv("Actual_Demand.csv", mode='w', header=True, index=False)
